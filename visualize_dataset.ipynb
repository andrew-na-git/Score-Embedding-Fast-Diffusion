# %%
from slurm.data.Dataset import CIFARDataset
import matplotlib.pyplot as plt

# %%
H = W = 32

ds = CIFARDataset(H, W, n = 1, seed = 9)
# Out:
# Files already downloaded and verified

# %%
for img in ds:
    plt.imshow(img.moveaxis(0, 2))
    plt.show()
