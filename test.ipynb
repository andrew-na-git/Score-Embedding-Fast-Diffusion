# %%
from slurm.data.Dataset import FlowersDataset
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = FlowersDataset(H=64, W=64)

# %%
plt.imshow(dataset[0].moveaxis(0, 2))

# %%
x = np.moveaxis(score, 0, 2)
plt.imshow((x - x.min())/(x.max() - x.min()))
