# %% [markdown]
# ## This notebook serves as a helper to visualize the datasets provided in this codebase

# %%
from Dataset import CIFARDataset, CelebDataset, ImageNetDataset

# %%
#ds = CIFARDataset(n_data=10, seed=9)
ds = CelebDataset(image_res=128, n_data=6)
#ds = ImageNetDataset(image_res=64, n_data=3)

# %%
ds.plot();
